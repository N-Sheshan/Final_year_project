# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Avulsion fracture/389382_jpg.rf.8cb98ee798766a2d3f6a76279ba5d0d9.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Avulsion fracture/avulsionlessertrochanter01jakpelvis15yo_jpg.rf.075c733923f27bd4611acf064a41a4e3.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Avulsion fracture/000002_png.rf.c3e00ebc2db78bc94e644c3f6605dad0.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Avulsion fracture/1b62e6fbfbc5a2f70c6af413189cfc82_jpg.rf.2761e933cc6d206308877cccaf0642b2.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Avulsion fracture/13256_2019_2325_Fig1_HTML_png.rf.09368fddb2da3979a3e1e25a0cac6f45.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Avulsion fracture/60683ca7a8a5848feda86d15_acl-avulsion-fracture-1_jpg.rf.17e17d797643e92164cc9825dc530399.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Avulsion fracture/220px-Avulsion_fracture_of_tibial_tuberosity2C_annotated_jpg.rf.aac7ac1f6ad2f7a822ee729f39b750af.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Avulsion fracture/13256_2019_2325_Fig1_HTML_png.rf.09368fddb2da3979a35a0cac6f45.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Avulsion fracture/9dcddacffaff8689cc1e9cedbe76a5_jumbo_jpeg.rf.7259a238161cf03dca23a3dd5369e0b1.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Avulsion fracture/1-s2-0-S0899707114002836-gr2_jpg.rf.bb8ed4dee892edbb760f6ce687d74ba5.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Avulsion fracture/9896089d1b31b0ba0158dc33122899_jumbo_jpeg.rf.d5e6b871460129728d2506e55476d496.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Avulsion fracture/5c7fec45769db28bdd107336f19004336689a4fb804b37af3096741f2879ff02_jumbo_jpeg.rf.68a4d14a09ed5baf1f8e1c1957ee5a01.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Avulsion fracture/31446tn_jpg.rf.fd1466bd9c9a7d604dc3e782f87b84d6.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Avulsion fracture/05cc2e0302957e0ad27edb6b9ffbc2_jumbo_jpg.rf.c15eb3758845b639f3aaba73c373501d.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Spiral Fracture/247_2019_4591_FL_jpg.rf.1035e160a9c7d7071e08.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Spiral Fracture/110001_jumbo_jpeg.rf.94b56c0454a24891c46456a32af0129c.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Spiral Fracture/247_2019_4591_Fig6_HTML_jpg.rf.1dc947109f035e160a9c7d7071e08.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Spiral Fracture/590_2014_1411_Fig1_HTML_jpg.rf.9d4ebc234c5605fa8336a4d522e89d48.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Spiral Fracture/0-_jumbo_jpeg.rf.7645898c0465d33bcd71ee0ddb847e0a.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Spiral Fracture/3-s2-0-B978012386456706706X-f06706-04-9780123864567_jpg.rf.dd278033e65199fdc2d4d2eca2c01f7b.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Spiral Fracture/192811243_jpg.rf.93989b0917199eb629709b79bf516da9.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Spiral Fracture/421220_jpg.rf.1231cb18431107345b2398be88e0e946.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Spiral Fracture/411477_jpg.rf.c1f2d0daec00e5d81484533bb0785af9.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Spiral Fracture/7590tn_jpg.rf.ffbf84219c6752e6e48c797746742f3b.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Spiral Fracture/590_2014_1411_Fig1_HTc234c5605fa8336a4d522e89d48.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Spiral Fracture/247_2019_4591_FL_jpg.rf.1dc947109f035e160a9c7d7071e08.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Impacted fracture/321642_2200-732x549_jpg.rf.4980857c522d36a62f9829fe86058076.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Impacted fracture/2021_04_07_19_24_6029_2021_04_07_Ulnar_Fracture_jpg.rf.731c2017d7a1d53d0eaf9ace647e8912.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Impacted fracture/20980tn_jpg.rf.08df4572fdeb34428103e11296500c19.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Impacted fracture/56a7a5e4ed51b2f23052775923c9c4_gallery_jpg.rf.d765fb7314c5833d49484b5f7f933477.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Impacted fracture/12891_2018_2170_Fig1_HTML_png.rf.2d45186e46a8dac72a42e99ecc1a957c.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Impacted fracture/4d0971c94b4213a016bcfc13296aa4_jumbo_jpg.rf.5031422aa36e5a481cc5993aa3b54a02.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Impacted fracture/3-s2-0-B9781782424499000042-f04-05-9781782424499_jpg.rf.697fc1f3f837a4facd89b17281dc3843.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Impacted fracture/0fd9c4957210d0c8324ccc00c39d243d_jpg.rf.7625244128c1f6a73965a0290b6e6c31.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Impacted fracture/300px-L4_compressionFracture2008_jpg.rf.d65b16f949aa860fb212af1dadbc9c3f.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Hairline Fracture/10195_2010_9ig2_HTML_jpg.rf.c12df3901db2a4b4e0952d10f5660ae0.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Hairline Fracture/402_2018_3035_Fig3_HTML_jpg.rf.c9959ea361358cf5ac4cf68c9096236f.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Hairline Fracture/2995c0750ed98208c238f4b6a27ddd_jumbo_jpg.rf.f3c327c6d4893a32a5bdf9d01f425028.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Hairline Fracture/7919tn_jpg.rf.43200f6cb2d72e3082805002b9f3a1f8.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Hairline Fracture/2bc441c91f63a9588fab405fde2ae3_jumbo_jpeg.rf.9b7b45ce86f1197b06bbfbdd736b8b55.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Hairline Fracture/640px-Cropped_version_of_Jonesfracture_jpg.r40958b7c85972169a63197313018.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Hairline Fracture/0-_jumbo_jpeg.rf.d39588df830d194c0cda3b800664160b.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Hairline Fracture/10195_2010_96_Fig2_HTML_jpg.rf.c12df3901db2a4b4e0952d10f5660ae0.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Hairline Fracture/640px-Cropped_version_of_Jonesfracture_jpg.rf.cbf840958b7c85972169a63197313018.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Hairline Fracture/2995c0750ed98208c238f4b6ad_jumbo_jpg.rf.f3c327c6d4893a32a5bdf9d01f425028.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Greenstick fracture/1-s2-0-S1930043321005148-gr1_jpg.rf.ea5be53ec584c7fa9e3e1ddba7210dd5.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Greenstick fracture/_Fracture_general_principles_fig04_Torus_Greenstick_fracture_BLANCO-1024x957_jpg.d0a0708a95fcb18cbbdf0af9de020488.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Greenstick fracture/7410b6b41bc4e99e1f93bab41283b1_jumbo_jpg.rf.72d8073f7a1382ca542077a8487a5a37.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Greenstick fracture/6550e902d0af421ad3b94f073620d1_gallery_jpeg.rf.c23760797e0bcc7af6ab14327062b17f.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Greenstick fracture/0-_jumbo_jpeg.rf.f83148ed2e6771e243f98f5595db6b9c.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Greenstick fracture/_Fracture_general_principles_fig04_Torus_Greenstick_fracture_BLANCO-1024x957_jpg.rf.d0a0708a95fcb18cbbdf0af9de020488.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Greenstick fracture/69f4dcb3b060206f0acaec9f0a25bf3a67ceb063d5e06889caea74ed65332482_jumbo_jpeg.rf.ea88d6dd7d4a8a9a47a31053ce9952e7.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Greenstick fracture/15ff6b9162cf7c04caad3fbd4f4a2e_gallery_jpg.rf.bdcd5db0dd212b125b361a70ddf63265.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Greenstick fracture/27947ea707d39e57b0c14db8fc93d3_jumbo_jpeg.rf.d7f9014c5a33717ff2b8f7213e38524b.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Greenstick fracture/5081d90aea64c_jpg.rf.236544b7b485ea3c53214f7c1ae90430.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Greenstick fracture/40926tn_jpg.rf.95b23c6c30cc0d022f5af322fe72b9ce.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Greenstick fracture/1-s2-0-S1930043321005148-gr1_j.rf.ea5be53ec584c7fa9e3e1ddba7210dd5.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Greenstick fracture/474345-58c87a400ed40ee60296b02ce19ee7dc_1_jpg.rf.31fd8bccbbf50f2664f3fab7a971f790.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Greenstick fracture/2560px-Greenstick_fracture2C_A-P_view_jpg.rf.290485498308a848fd2518e20b0426b1.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Greenstick fracture/001_jumbo_jpeg.rf.ebf440662388fc36df361ce39890acb2.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Greenstick fracture/247_2019_4591_Fig4_HTML_jpg.rf.55ba8a51eb38363815c04444d7dcd509.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Pathological fracture/1b_jpg.rf.45e283da037d29a26ffb44f397bcc1a1.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Pathological fracture/0c70d9cb6ae7fcf9faae2dc812af08_gallery_jpg.rf.77bf31aa996b57613189b8de7e1d29fd.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Pathological fracture/2-Figure1-1_png.rf.9e804429de51de6c6e8590ce31f571a9.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Pathological fracture/1-s2-0-S1877056815003461-gr3_jpg.rf.d559b8f4656b96c7d8c9f5a0b4904eb5.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Pathological fracture/2-Figure1-1_png.rf.9e804429de51de6c690ce31f571a9.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Pathological fracture/1-s2-0-S1877056815003461-gr1_jpg.rf.ecdb5a0a245d628f490c02ba81171284.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Pathological fracture/1-s2-0-S1877056815003461-gr6_jpg.rf.ad4975a86d23505ff95c659bf9b7319a.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Pathological fracture/5e26814a794fb50001390d1c_jpg.rf.544fc6bcf14e69c89637e7e6453d515b.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Pathological fracture/8-2010728x6_png.rf.92b0fe8076d882c69c6528b.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Pathological fracture/1-s2-0-S1877056815003461-gr1_jpg.rf.ec0a245d628f490c02ba81171284.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Pathological fracture/8-2010728x6_png.rf.92b0fe8076d88866d5e4792c69c6528b.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Pathological fracture/5b15c2accb90c7880e90b2ca70ec9e28_jpg.rf.1eedf24749b4cb2037bfae26f918f7e8.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Pathological fracture/1-s2-0-S2352187216300080-gr1_jpg.rf.477e8e5de5f8e589b07827541c666829.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Pathological fracture/2b092d94ab7a1cdd41f5853d807d86e1_jpg.rf.6586c0707d53092752ac91bfe141856c.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Pathological fracture/2-Figure3-1_png.rf.c51b89ee7be9053a5d4c6df08fd5a852.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Pathological fracture/1-s2-0-S1877056815003461-gr6_jpg.rf.ad4975a23505ff95c659bf9b7319a.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Pathological fracture/10-1302_2058-5247_jpeg.rf.9672030e7caa4b22d386e38317dab60c.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Pathological fracture/10-1302_2058-5247_jpeg0e7caa4b22d386e38317dab60c.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Oblique fracture/0-_gallery_jpeg.rf.b3170266ea6b6d03bfb4ae5991df98ce.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Oblique fracture/10-1055-b-002-85516_c023_f003-1_jpg.rf.a2cb46deb0263fc92980f45ee328c632.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Oblique fracture/A-radiograph-shows-completely-displaced-short-oblique-fracture-of-the-right-femur-shaft_png.rf.ccee1b8ade24a3ca729780cd9563cf26.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Oblique fracture/2624240dc461d0c5d2d7fb7e16b3065c_jpg.rf.628b0bc8b7bb91626b4835d7b36293b6.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Oblique fracture/6355f23b1cf9e11781e91f6af08293_jpg.rf.b4349082bc63bd7f3623633c67cebe25.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Oblique fracture/493071_0_En_4_Fig9_HTML_jpg.rf.5d14a5beb171c842378a96949b7ac6.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Oblique fracture/493071_0_En_42-1_Fig9_HTML_jpg.rf.5df14a5beb171c842378a962949b7ac6.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Oblique fracture/ankle20per4_jpg.rf.c2cc3850df30ebbc01f5e97b7d812ea0.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Oblique fracture/493071_0_En_4_Fig9_HTML_jpg.rf.5d14a5beb171c2378a96949b7ac6.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Oblique fracture/43390tn_jpg.rf.e82c12a328a56cc66d5d828e638324be.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Oblique fracture/493071_0_En_4_Fig9_HTML_jpg.rf.5df14a5beb171c842378a96949b7ac6.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Oblique fracture/1000_F_264769365_u927dRxrrx1fi4rlR1VWif9LcGeJwv4h_jpg.rf.b2d149cb90da63cbc49ec73e82bf0935.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Oblique fracture/493071_0_En_42-1_Fig9_HTML_jpg.rf.5df14a5beb171c842378a96949b7ac6.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Oblique fracture/10-1055-b-002-85516_c023_f003-1_jpg.rf.a2cb46deb0263fc9290f45ee328c632.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Oblique fracture/119913828-radiography-with-oblique-fibula-fracture_jpg.rf.8f0f4e48c3c959ca7b930e3cba8fafd0.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Oblique fracture/220px-MalletFinger-PNG_jpg.rf.8eb8b19e344b2ab4d48b4cbeda7b4a80.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Fracture Dislocation/22097c143c33367ce6a14aab180507_jumbo_jpeg.rf.dba2616edbc6752417d3acf6acee8e6d.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Fracture Dislocation/9c1cbdeaa3a92cda049b03cfc58323_jumbo_jpeg.rf.96d8da3e8e693938cf66f704952d954b.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Fracture Dislocation/847b5a158bed0311bf28b5cd647088_jumbo_jpg.rf.271ac7bed7b0dc447ad19199a5292c3d.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Fracture Dislocation/1A_jpg.rf.0677856a44a86c9ddca947bda2.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Fracture Dislocation/77f8f82dd8cdcf805923a93b0185e1_gallery_jpeg.rf.63372be12ae61d75d4c632618aaadaeb.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Fracture Dislocation/47yoMcentralhip_jpg.rf.6b862323b37cef4bf7c2131d48c837da.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Fracture Dislocation/1-s2-0-S1268773120301892-gr1_rf.a87a221ae10f0f11bf1e72867576588b.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Fracture Dislocation/0f2621347d6757e99604be62938184_jumbo_jpg.rf.525e9b9d5a24047c4a22bbdd53cd1b2e.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Fracture Dislocation/89a0646700fc2a62049ff99073ce5d_jumbo_jpeg.rf.c56cb1e33641b1217effd83c152f1a02.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Fracture Dislocation/1A_jpg.rf.0677856b851eba44a86c9ddca947bda2.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Fracture Dislocation/10-1055-b-004-129594_c035_f022_jpg.rf.79ff9d90432220e3d36eee868f6467f9.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Fracture Dislocation/1-s2-0-S1268773120301892-gr1_jpg.rf.a87a221ae10f0f11bf1e72867576588b.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Fracture Dislocation/86bc033b86310ef27328c4b723226a_jumbo_jpeg.rf.7dd422b4ebf41ac2a0d5043f304b7c1a.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Fracture Dislocation/1A_jpg.rf.0677856a44a86c9ddcbda2.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Fracture Dislocation/0b0927c9e289f1b59085553d3ad46cf08b9566b76aa840d0a17d33c6e626825d_gallery_jpeg.rf.59cd1582385c6b6fbe54afaa63d5099e.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Fracture Dislocation/29b6a23fc1e531976fdb651cdf0670_jumbo_jpeg.rf.54234605109401278f08c8cd98edf6c6.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Fracture Dislocation/86bc033b86310ef27328c4b723226a_jum422b4ebf41ac2a0d5043f304b7c1a.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Fracture Dislocation/0-_jumbo_jpeg.rf.29079abb47d5de12076aed66aea08064.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Fracture Dislocation/10-1055-b-004-129594_c035_f009_jpg.rf.f834d08add09dc9092c544481c2b8907.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Longitudinal fracture/35d36ae9df9a48426f94b75d0f2939_jumbo_jpeg.rf.c0eebf1735c43ba5de01d321ce10748a.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Longitudinal fracture/1-s2-0-S235204771630003X-gr2_jpg.rf.23497906a4b6a3106d193648e244cc6e.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Longitudinal fracture/000008_jpg.rf.7672c617956d755d6e0e935f1e9c9d38.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Longitudinal fracture/488c4ff0bb5278bbf87f4c0e981dd6_gallery_jpg.rf.87d2f936037e0dfc1614f7518316a543.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Longitudinal fracture/21a4e1e58df56b97092f93d8c1c230_jumbo_jpeg.rf.fa12dc139f2460747c7aab3231101fc1.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Longitudinal fracture/7d6985744a7187e8af927146b0c2425e_f12207_jpg.rf.2fc543dad580f8ea8d7d4105ca8e4300.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Longitudinal fracture/544x728_BODY_Fibula_Fracture_jpg.rf.bb33fd70d075eed4226b2835138e867f.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Longitudinal fracture/000007_jpg.rf.7cf716c605db163a55eb6214c77bfb73.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Longitudinal fracture/300px-Medical_X-Ray_imaging_NJR06_Nevit_nasal_bone_fracture_jpg.rf.f482a70f53e8ceac96b6ee215badf095.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Longitudinal fracture/2-Figure1-1_png.rf.515ecc51fd0ec33b35a671d379c1485f.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Longitudinal fracture/8644c7aa15b332130711e15a541800_gallery_jpg.rf.3c08725e91f0227003510b63f8d2ae27.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Longitudinal fracture/2-Figure1-1_png.rf.515ecc51fd0ecc1485f.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Comminuted fracture/open-fracture-tibia_jpg.rf.792969425566c2fe5437ac8a1aa400dc.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Comminuted fracture/images99_jpg.rf.52c1ae7d26ef95067175fe511216338a.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Comminuted fracture/leg-displacement-two-projections-white-background-vertical-image-x-248620996_jpg.rf.15fe0e9e9b93d8870cbc808e994bf03e.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Comminuted fracture/Picture1_jpg.rf.8f2419c6c065392dfad896e83f29f0cf.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Comminuted fracture/Radiograph-showing-a-comminuted-fracture-of-the-middle-third-of-the-right-femur-in-a_png.rf.ade9ed22124189b5d0f8cd51b03033e2.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Comminuted fracture/IMG-0001-00001_jumbo_jpeg.rf.4af5e7c047bac2007869a5e19663eb77.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Comminuted fracture/images96_jpg.rf.1d432bc0a70d58cc78b19f48746b3f02.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Comminuted fracture/images95_jpg.rf.54b02400b9746a0aafc2c9b4d6d98332.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Comminuted fracture/images94_jpg.rf.1be75680f0289a4d2bcc8d0c112a3453.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Comminuted fracture/images98_jpg.rf.411320e212e6bd90114d4f8832a7fc1c.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Comminuted fracture/T1507F01_Fig03B_jpg.rf.ca5bf37cc498403dd7bc84931bda4253.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Comminuted fracture/X-ray-2-comminuted-displaced-fracture_png.rf.ace79e6f0ec1e6ec4037943cc83c14d4.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Comminuted fracture/X-ray_of_a_comminuted_hip_fracture_jpg.rf.6725d6fabfddc890e45180cf483808a9.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/val/Comminuted fracture/preop-x-ray-showing-badly-comminuted-fracture-proximal-tibia-rama-krishna-hospital_jpg.rf.3662dfd3b1b367d8e8eb71178999dbe8.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/MalletFinger-PNG_jpg.rf.6ba864d6512079c3aa42b86feeb424d1.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/9781604064797_ch092_f001_jpg.rf.89e30c33eebe51177be42787ddaa7745.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image31_jpeg.rf.c31b74efca3394ab54c71a1e5ac50306.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/images22_jpg.rf.f66863f67a82f47a67f263e410ee8d4a.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/images13_jpg.rf.1cda91b014c68ffe86a6fa06ac89eb9a.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/ray-showed-an-avulsion-fracture-at-the-base-of-DP_Q320_jpg.rf.9e506395a15ac5083ee709c17345558c.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/Inked2d59fd50936098df8ddf49c912e70b_gallery_jpg.rf.0a4f68fb0c9bcea262bbdf6061f_LI_Moment.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/images3_jpg.rf.de0165f64aa6a64ce3dd9552eb0165b7.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/94f6a-pclavulsion1a_png.rf.621b9fb0ecda5666f169e06b88d35b9e.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/2-Figure1-1_png.rf.d9c1a18069444475adbb477d440ce0e9.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image3_jpeg.rf.70e5a26cf73c48a5692c11c1deea98e4.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/gr1_lrg_jpg.rf.bf893d54341142976a0672dd088ded3d.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image28_jpeg.rf.99fe6c384f84967b5c5ef00bb70d6741.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/800px-Left_lateral_malleolus_avulsion_fracture_detail_jpg.rf.9465bfeae560e0d37a57e6096249c030.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image7_jpeg.rf.cdf517093bf5477debbf9bb78a330625.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image210_jpeg.rf.a9a08c3f3525414fd0689593e631ce5.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/tibial-spine_-avulsion_jpg.rf.275ac4b79ba72cb8b3e7f507271fdf42.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image19_jpeg.rf.83625b51238263f7220c91aab55d5aa0.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image22_jpeg.rf.45894d44324a7251eb5d3af227bdd003.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image12_jpeg.rf.6e3f63e525a932c38c3bed3c97a48f5e.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image30_jpeg.rf.e406e467fb037f74a616a004be642212.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image21_jpeg.rf.0626d85b6de6fed9102a1a4eb179c7f3.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image9_jpeg.rf.4f7d7cb5a7a3ff33253bb4769fdaf32c.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/cow539-3_jpg.rf.71e336264ac124aeb83eb286373554da.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/slide_5_jpg.rf.633ceaa5b85a07c9fab2ef182e12bc72.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/Segond-Fx-label-2_png.rf.ebecbcb0ff895e7e06cb974569469.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/images_jpg.rf.0ce1d5a7ca4c319ff39d444e5df37f3f.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/SaudiJSportsMed_20465_u1_jpg.rf.90c56f07b7728660ce6cfba13e332f6d.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image10_jpeg.rf.b566b1f5626a3292fe805699e784a175.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/images7_jpg.rf.c4419176d2a7d3f8e26f04a4e4a82cf7.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image20_jpeg.rf.66d531034ff0808d7988f5de176b10fa.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/images5_jpg.rf.9aef7c8db80fe7194a89674aae2a0838.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/Segond-Fx-label-2_png.rbecbcb0ff8e7e06cb974569469.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/spine_jpg.rf.9ba16757b6874ae00f935cc8eae5.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/jum14189-fig-0003-m_jpg.rf.8c08987a911f109ccc695630259c4071.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/peroneal-avulsion_png.rf.f99934ab4ea691283e934c3eec1a542d.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/Left-knee-AP-and-lateral-radiographs-showing-avulsion-fracture-of-the-tibial-tuberosity_jpg.rf.b13178133904e8c6fe26875bcef812a2.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image24_jpeg.rf.c27397dcbd767c2e575db5eaf2e4b20d.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/35765-galleyfig1a_jpeg.rf90773a110b4171d25a.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image30_jpeg.rf.e406e467fb037f74a61604be642212.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/e35976_4fe265db4c064d53bc55e857fbecc28dmv2_png.rf.48ff6ace881ba10b5937fd534990c4f6.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image5_jpeg.rf.f61b5e479448497066f77237b9d084f9.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/images10_jpg.rf.e1ad8c3effdf417ef7e6ec06dfeebc15.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/Left-knee-AP-and-lateral-radiographs-showing-avulsion-fracture-of-the-tibial-tuberosity_jpg.rf.b131781339048c6fe26875bcef812a2.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/g08oc12g10a_jpeg.rf.b3c91a586684ff23feec0e24add35b5b.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/Inked2d59fd50936098df8ddf49c912e70b_gallery_jpg.rf.0a4f68fb0c9b522ce75a26df6061f_LI.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/697306b5c3755dd70645ac1a714fce3b_jpg.rf.21b53660b2fd76db08a98e9dad5d8d4f.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/Inkedcalcanealavulsionfx_png.rf.ff0595970365ef9d194318f215ccbc26_LI.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/35765-galleyfig1a_jpeg.rf62790773a110b4171d25a.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image4_jpeg.rf.fcb144c2ca481bd5d99340ba46574506.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/images6_jpg.rf.f29e7c4f796ef2a38a055ec325194fab.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image26_jpeg.rf.67555d2f3465a28984327b08ec6c0325.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/F1-large4_jpg.rf.4252b8d03c32b5e5299279de5619cc.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/jbsr-104-1-2180-g1_png.rf.dbeb8e4b12c378e082b7f753eb60a.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/SaudiJSportsMed_2017_17_1_22_197465_u1_jpg.rf.90c56f07b7728660ce6cfba13e332f6d.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/FTCjoRnWQAMETYF_jpg.rf.662d6aa8680d248cac375a7256e0fa3f.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/35765-galleyfig1a_jpeg.rf.4e4f1d462790773a110b4171d25a.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/cow539-2_jpg.rf.6016bc74fad63aefd02c973b2a7994f0.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/knee-X-rays-showing-a-displaced-avulsion-fracture-of-the-tibial-tuberosity_jpg.rf.e16eee5a24caa9e868c41554ed1c3620.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image18_jpeg.rf.9d59531f4a8ac9f6a09d34b858e56cea.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/F1-large2_jpg.rf.c2d3078f808a8a85ce1563a8b857820d.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/images_jpg.rf.0ce1d5a7ca4c319ff39d4445df37f3f.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image31_jpeg.rf.c31b74efca3394ab4c71a1e5ac50306.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image6_jpeg.rf.705e5cb2166c15baf86ae05ae1c534bb.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/jum14189-fig-0003-m_jpg.rf.8c08987a911f109ccc695659c4071.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/jospt-620-fig001_jpg.rf.a6c6b3ecde58b099587c889367527cac.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/tcr-5-078-001_jpg.rf.d4099231ae325a7cbcaa0488a5882079.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/jbsr-104-1-2180-g1_png.rf.d25dbeb8e4b12c378e082b7f753eb60a.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/images26_jpg.rf.1b82fb47010737394b99f8f0d5eb9d6d.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/cow539-4_jpg.rf.e48668495cb14d0493e092b1ff23c4fe.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/cow205lg_jpg.rf.80b53235cf34318f1b3973ef5eb9627a.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image11_jpeg.rf.4da4acf6d2c1d061687b597494c6ee8c.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/images2_jpg.rf.004dfc1919a390d5e6c93b5634105a66.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/images9_jpg.rf.c7cfaf208f09581e9eae3e22174f9509.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/images21_jpg.rf.0ef452a83232fc2e6705bd968fa29737.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/SaudiJSportsMed_2021_21_2_69_327488_f1_jpg.rf.7acce1c23e10ac231fa340b32dc2.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image25_jpeg.rf.ce36231a54a62ee9d6ebbafc0fd859ea.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/697306b5c3755dd70645acfce3b_jpg.rf.21b53660b2fd76db08a98e9dad5d8d4f.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/knee-X-rays-showing-a-displaced-avulsion-fracture-of-the-tibiauberosity_jpg.rf.e16eee5a24caa9e868c41554ed1c3620.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/e35976_4fe265db4c064d53bc55e857fbecc28dmv2_png.rf.48ff6ace881ba10b5937fd34990c4f6.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/Left_lateral_malleolus_avulsion_fracture_jpg.rf.83d50e146146ab622ad5fa95e5d3d2f5.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image14_jpeg.rf.359749fca105f483ac0fdf9973fec7ee.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/jcs372-g001_jpg.rf.c7a28478b9626ae41e243f25c2618e95.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/spine_jpg.rf.9ba16757b6874ae943c00f935cc8eae5.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/12891_2019_2585_Fig5_HTML_png.rf.e7f1f0cb0b6723cde402057336779890.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/697306b5c3755dd70645acfce3b_jpg.rf.1b53660b2fd76db08a98e9dad5d8d4f.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/Pre-operative-X-ray-shows-avulsion-fracture-of-the-fibular-head-without-dislocation-of_png.rf.e7b4718d35f57eb561940fa4509d1cf2.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/Pre-operative-X-ray-shows-avulsion-fracture-of-the-fibular-head-without-dcation-of_png.rf.e7b4718d35f57eb561940fa4509d1cf2.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/F1-large_jpg.rf.a6f3a67ddd8ce10a037193d8121b5bea.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/Segond-Fx-label-2_png.rf.ebecbcb0f575f895e7e06cb974569469.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/SaudiJSportsMed_2021_21_2_69_327488_f1_jpg.rf.7accebb5e1c23e10ac231fa340b32dc2.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image27_jpeg.rf.04e6a6566836e916582714dfb62d7c13.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/images24_jpg.rf.09d198828844a4334157a33d88625c3b.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image23_jpeg.rf.e356cb69158aed1da5d1fda94acc09df.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/Pelvic_4_jpg.rf.ffd15f48b6fb3dbd95c59e02c6ef946b.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image18_jpeg.rf.9d59531f4a8ac9f6a04b858e56cea.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/F1-large4_jpg.rf.4252b8d03c32b5e529927f9de5619cc.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/Segond-Fx-label-2_png.rf.ebecbcb0ff8e7e06cb974569469.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/Pelvic_2_jpg.rf.f1d594abda0640caa3c3a07c99091f7e.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/lightbox_1822d4007d9b11eab7338708af0fabaf-IMG_20191029_122622-2-_png.rf.90495f17b148a38bbd74de2818c6b36b.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image210_jpeg.rf.a9a08c3f3525414fd06895935e631ce5.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image13_jpeg.rf.629135763282eca324d34d3bdde57075.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/images15_jpg.rf.791e6a68039a07804cc5c7e714abffd7.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/images20_jpg.rf.62aeaabb8aa2467371f2f9f4838495f9.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/g08oc12g13a_jpeg.rf.fb2516cd00452087ae81453b856e5eb7.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/images16_jpg.rf.d505cf1bdaa5e3f74e3c3f6bd2145185.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/arm-39-473-g002_jpg.rf.6148aa4ee9d3a52d47dfd2131450cb5d.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/g08oc12g07b_jpeg.rf.c5d8e582e388077397dc7f5418ec818c.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Avulsion fracture/image8_jpeg.rf.7e052c435cfae6bfa73077eacacf710f.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Spiral Fracture/leg-xray-showing-closed-spiral-260nw-1586443063_jpg.rf.6f2b0447a8ac974f0000efae7a34bb07.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Spiral Fracture/image17_jpeg.rf.d68b6dfb38a6cbfeec4ad3e484722720.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Spiral Fracture/fracture-tibia-242x300_jpg.rf.bd80b6904d8ea8638a621e5012dcf525.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Spiral Fracture/images20_jpg.rf.1edb02c282bd8a993a486571dba82a30.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Spiral Fracture/image26_jpeg.rf.b136aa1eeb4b2089daa60e63367966b4.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Spiral Fracture/images21_jpg.rf.c217a6c4eedb570177ac5f6343d3ae0e.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Spiral Fracture/c0394402-800px-wm_jpg.rf.30b465723aff3c6062a04f64870b75e1.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Spiral Fracture/al-fracture-of-distal-fibula-at-level-of-syndesmosis-with-minimal-1286218351_jpg.rf.33383cf09fd6c5df2f71c2eb9c417731.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Spiral Fracture/image12_jpeg.rf.82b0cf0313c9a15432fa0f3ad9b8fad8.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Spiral Fracture/broken-humerus-xray-showing-compound-260nw-666295192_jpg.rf.f0dc1d9f84267947607311ec7d87f449.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Spiral Fracture/PruchaFig1e0f228cf67f39df1de4eb173c2acfd9.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Spiral Fracture/image6_jpeg.rf.df2fa03135b4262ad6dec8126e3896a0.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Spiral Fracture/e5025a324f95b26770f89f95a065a6_jpg.rf.ece1ba8959ced95f8df2698ef6c5555a.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Spiral Fracture/images16_jpg.rf.0eb5b4b3cdd9b94be44c7b3a07adddcf.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Spiral Fracture/RIGHT_leg_jumbo_jpeg.rf.5c79a192709e4e90f860d7e0a42fd25f.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Spiral Fracture/JOrthopDisTraumatol_2020_3_3_116_305736_f2_jpg.rf.ac4dd6737bdd1de1e02fb014c52e79e1.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Spiral Fracture/xray-film-spiral-fracture-third-metacarpal-bone-with-3-metallic-artifacts_78455-923_jpg.rf.4c8692f0a5dc6c95c9d400458d94e6ed.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Spiral Fracture/image21_jpeg.rf.ba8d71a706dea1673b731323a1219a7e.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Spiral Fracture/A-Plain-radiograph-shaft-and-multiple-scattered_Q640_jpg.rf.7d83c56445dd5e9a7334a7d49569fdda.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Spiral Fracture/images12_jpg.rf.9d37cb8278ca2a9f4463de9c34102594.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Spiral Fracture/Maisonneuve_fracture_Fibula-JPG_jpg.rf.56c8fcbb6a05401e12c747f35dfafc5a.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Spiral Fracture/A-Plain-radiograph-spiral-in-left-femoral-shaft-and-multiple-scattered_Q640_jpg.rf.7d83c56445dd5e9a7334a7d49569fdda.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Spiral Fracture/image2_jpeg.rf.5ea676b2e01ff0234b147af30240abe8.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Spiral Fracture/spiral-fracture-lower-tibia_jpg.rf.b0dee5f894823b9d1511a648f61c8b53.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Spiral Fracture/images3_jpg.rf.867087966ee2106c7462017bad4e22c6.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Spiral Fracture/x-ray-side-of-skull-and-spine_jpg.rf.42c81b4c58a8971f8bb052bff41189ad.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Bone Break Classification/train/Spiral Fracture/images2_jpg.rf.a21a6639bab18fd8b92901866f24e8c3.jpg
# ...
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0112.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1206.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1249.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0316.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0669.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0037.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1015.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0688.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0933.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0262.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0672.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0333.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0690.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0912.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0174.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0634.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0076.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1225.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0161.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0045.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0973.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0318.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0723.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1043.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0243.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0398.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0802.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0850.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0108.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0603.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0558.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0277.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0018.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1085.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1055.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1185.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1243.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0057.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0947.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0235.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0150.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0021.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0600.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0250.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0946.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0303.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1102.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0663.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1224.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0884.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0162.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0056.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0523.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0887.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0546.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0160.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0131.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1013.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1304.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0736.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0705.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1281.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1118.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0734.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0238.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0145.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1155.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0642.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0255.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0204.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1187.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0680.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0409.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0786.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0111.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0040.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0978.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0220.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0693.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0218.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0434.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0148.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0139.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0716.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0876.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0064.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0335.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1081.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0187.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1302.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0625.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0221.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1042.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0791.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0314.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0686.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0234.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0749.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1195.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0651.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0615.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0118.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1075.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1167.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0532.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0920.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1143.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1188.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1069.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0613.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1067.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0440.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0254.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0534.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0285.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0381.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0996.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0242.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1171.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0189.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0896.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1313.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0429.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0054.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0984.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0510.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1103.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0899.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0750.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0545.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0441.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1084.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1124.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0779.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0195.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1032.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0411.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0953.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0116.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0578.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0659.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0253.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_0492.jpg
# /kaggle/input/updated-medical-image-dataset/new_dataset/Brain Tumor Classification/train/glioma/Tr-gl_1037.jpg

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, random_split, ConcatDataset
from torchvision import transforms
from PIL import Image
import numpy as np
from tqdm import tqdm
from vit_pytorch import ViT

# %%
# Dataset Class
class MedicalImageDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.image_paths = []
        self.labels = []
        self.class_to_idx = {}
        
        self.load_images()

    def load_images(self):
        """
        Load images from the dataset directory.
        Assumes directory structure: root_dir/train_or_val/class/image.jpg
        """
        for subset in ['train', 'val', 'test']:  # Add more subsets if needed
            subset_path = os.path.join(self.root_dir, subset)
            
            if os.path.exists(subset_path):
                for class_name in os.listdir(subset_path):
                    class_path = os.path.join(subset_path, class_name)
                    
                    if os.path.isdir(class_path):
                        # Add class to mapping if not already exists
                        if class_name not in self.class_to_idx:
                            self.class_to_idx[class_name] = len(self.class_to_idx)
                        
                        # Load images for this class
                        for img_name in os.listdir(class_path):
                            img_path = os.path.join(class_path, img_name)
                            
                            if img_name.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tif')):
                                self.image_paths.append(img_path)
                                self.labels.append(self.class_to_idx[class_name])

        print(f"Found {len(self.image_paths)} images across {len(self.class_to_idx)} classes")
        print("Class mapping:", self.class_to_idx)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        label = self.labels[idx]

        try:
            image = Image.open(img_path).convert("RGB")
        except Exception as e:
            print(f"Error loading image {img_path}: {e}")
            # Return a dummy image to prevent training interruption
            image = Image.fromarray(np.zeros((224, 224, 3), dtype=np.uint8))

        if self.transform:
            image = self.transform(image)

        return image, label

# %%
# Data Augmentation and Normalization
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
# Model Creation
def create_model(num_classes):
    model = ViT(
        image_size=224,
        patch_size=16,
        num_classes=num_classes,
        dim=512,
        depth=6,
        heads=8,
        mlp_dim=1024,
        dropout=0.1,
        emb_dropout=0.1
    )
    
    # Wrap the model for multi-GPU support
    if torch.cuda.device_count() > 1:
        print(f"🚀 Using {torch.cuda.device_count()} GPUs!")
        model = nn.DataParallel(model)
    
    # Move model to GPU
    model = model.to(DEVICE)
    
    return model

# %%
def train_model(model, train_loader, valid_loader, num_epochs=15, learning_rate=1e-4):
    criterion = nn.CrossEntropyLoss().to(DEVICE)
    optimizer = optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=0.01)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)

    best_val_accuracy = 0.0

    for epoch in range(num_epochs):
        # Training Phase
        model.train()
        train_loss = 0.0
        train_correct = 0
        train_total = 0

        progress_bar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs}")
        for images, labels in progress_bar:
            images, labels = images.to(DEVICE), labels.to(DEVICE)

            optimizer.zero_grad()
            
            with torch.cuda.amp.autocast():
                outputs = model(images)
                loss = criterion(outputs, labels)
            
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            train_total += labels.size(0)
            train_correct += (predicted == labels).sum().item()

            progress_bar.set_postfix({
                'Loss': f'{loss.item():.4f}', 
                'Accuracy': f'{100 * train_correct / train_total:.2f}%'
            })

        # Validation Phase
        model.eval()
        val_loss = 0.0
        val_correct = 0
        val_total = 0

        with torch.no_grad():
            for images, labels in valid_loader:
                images, labels = images.to(DEVICE), labels.to(DEVICE)
                
                with torch.cuda.amp.autocast():
                    outputs = model(images)
                    loss = criterion(outputs, labels)
                
                val_loss += loss.item()
                _, predicted = torch.max(outputs, 1)
                val_total += labels.size(0)
                val_correct += (predicted == labels).sum().item()

        train_accuracy = 100 * train_correct / train_total
        val_accuracy = 100 * val_correct / val_total

        print(f"Epoch {epoch+1}: "
              f"Train Loss: {train_loss/len(train_loader):.4f}, "
              f"Train Accuracy: {train_accuracy:.2f}%, "
              f"Val Loss: {val_loss/len(valid_loader):.4f}, "
              f"Val Accuracy: {val_accuracy:.2f}%")

        scheduler.step()

        # Save best model
        if val_accuracy > best_val_accuracy:
            best_val_accuracy = val_accuracy
            torch.save(model.state_dict(), "best_medical_vit_model.pth")

    return model

# %%
# Main Execution
def main():
    # Configuration
    BASE_PATH = r"/kaggle/input/updated-medical-image-dataset/new_dataset"  # Update with your path
    BATCH_SIZE = 32
    EPOCHS = 15
    LEARNING_RATE = 1e-4

    # Set the device globally
    global DEVICE
    DEVICE = get_device()

    # Initialize datasets for each task
    task_datasets = []
    all_class_to_idx = {}

    # Iteratively load datasets for each task
    for task_folder in os.listdir(BASE_PATH):
        task_path = os.path.join(BASE_PATH, task_folder)
        if os.path.isdir(task_path):
            task_dataset = MedicalImageDataset(task_path, transform=transform)
            
            # Only add non-empty datasets
            if len(task_dataset) > 0:
                task_datasets.append(task_dataset)
                all_class_to_idx.update(task_dataset.class_to_idx)

    # Combine all datasets
    full_dataset = ConcatDataset(task_datasets)

    # Print total dataset size
    total_size = len(full_dataset)
    print(f"Total dataset size: {total_size}")

    if total_size == 0:
        raise ValueError("No images found in the dataset. Please check your dataset directory structure.")

    # Split dataset
    train_size = max(1, int(0.7 * total_size))
    valid_size = max(1, int(0.2 * total_size))
    test_size = total_size - train_size - valid_size

    train_dataset, valid_dataset, test_dataset = random_split(
        full_dataset, 
        [train_size, valid_size, test_size],
        generator=torch.Generator().manual_seed(42)
    )

    # DataLoaders
    train_loader = DataLoader(
        train_dataset, 
        batch_size=BATCH_SIZE, 
        shuffle=True, 
        num_workers=4,
        pin_memory=True,
        persistent_workers=True
    )

    valid_loader = DataLoader(
        valid_dataset, 
        batch_size=BATCH_SIZE, 
        shuffle=False, 
        num_workers=4,
        pin_memory=True,
        persistent_workers=True
    )

    num_classes = len(all_class_to_idx)
    print(f"Number of classes detected: {num_classes}")

    # Create and train model
    model = create_model(num_classes)
    trained_model = train_model(model, train_loader, valid_loader, num_epochs=EPOCHS, learning_rate=LEARNING_RATE)

    # Final model save
    torch.save(trained_model.state_dict(), "final_medical_vit_model.pth")
    print("✅ Model training complete!")

# %%
if __name__ == "__main__":
    main()
# Out:
# ✅ GPU Available: Tesla P100-PCIE-16GB
#    CUDA Version: 12.1
#    cuDNN Version: 90100
#    Total GPU Memory: 15.89 GB
# Found 1129 images across 10 classes
# Class mapping: {'Avulsion fracture': 0, 'Spiral Fracture': 1, 'Impacted fracture': 2, 'Hairline Fracture': 3, 'Greenstick fracture': 4, 'Pathological fracture': 5, 'Oblique fracture': 6, 'Fracture Dislocation': 7, 'Longitudinal fracture': 8, 'Comminuted fracture': 9}
# Found 387 images across 7 classes
# Class mapping: {'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 0, 'normal': 1, 'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 2, 'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 3, 'squamous.cell.carcinoma': 4, 'adenocarcinoma': 5, 'large.cell.carcinoma': 6}
# Found 3297 images across 2 classes
# Class mapping: {'benign': 0, 'malignant': 1}
# Found 7023 images across 4 classes
# Class mapping: {'pituitary': 0, 'notumor': 1, 'meningioma': 2, 'glioma': 3}
# Total dataset size: 11836
# Number of classes detected: 23
# Epoch 1/15:   0%|          | 0/259 [00:00<?, ?it/s]<ipython-input-72-ea4266442ef8>:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Epoch 1/15: 100%|██████████| 259/259 [00:31<00:00,  8.30it/s, Loss=0.6994, Accuracy=51.29%]
# <ipython-input-72-ea4266442ef8>:48: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Epoch 1: Train Loss: 1.2416, Train Accuracy: 51.29%, Val Loss: 0.9039, Val Accuracy: 64.93%
# Epoch 2/15: 100%|██████████| 259/259 [00:30<00:00,  8.41it/s, Loss=1.0434, Accuracy=65.03%]
# Epoch 2: Train Loss: 0.8850, Train Accuracy: 65.03%, Val Loss: 0.7581, Val Accuracy: 71.65%
# Epoch 3/15: 100%|██████████| 259/259 [00:30<00:00,  8.43it/s, Loss=0.6284, Accuracy=70.33%]
# Epoch 3: Train Loss: 0.7622, Train Accuracy: 70.33%, Val Loss: 0.7122, Val Accuracy: 73.38%
# Epoch 4/15: 100%|██████████| 259/259 [00:30<00:00,  8.41it/s, Loss=0.3240, Accuracy=71.99%]
# Epoch 4: Train Loss: 0.7135, Train Accuracy: 71.99%, Val Loss: 0.6742, Val Accuracy: 72.96%
# Epoch 5/15: 100%|██████████| 259/259 [00:30<00:00,  8.42it/s, Loss=0.7716, Accuracy=74.25%]
# Epoch 5: Train Loss: 0.6580, Train Accuracy: 74.25%, Val Loss: 0.7164, Val Accuracy: 71.36%
# Epoch 6/15: 100%|██████████| 259/259 [00:30<00:00,  8.43it/s, Loss=0.5874, Accuracy=74.79%]
# Epoch 6: Train Loss: 0.6445, Train Accuracy: 74.79%, Val Loss: 0.6459, Val Accuracy: 76.00%
# Epoch 7/15: 100%|██████████| 259/259 [00:30<00:00,  8.43it/s, Loss=0.8248, Accuracy=75.82%]
# Epoch 7: Train Loss: 0.6049, Train Accuracy: 75.82%, Val Loss: 0.6293, Val Accuracy: 75.67%
# Epoch 8/15: 100%|██████████| 259/259 [00:30<00:00,  8.42it/s, Loss=0.7656, Accuracy=77.45%]
# Epoch 8: Train Loss: 0.5804, Train Accuracy: 77.45%, Val Loss: 0.5946, Val Accuracy: 76.17%
# Epoch 9/15: 100%|██████████| 259/259 [00:30<00:00,  8.44it/s, Loss=0.9229, Accuracy=78.27%]
# Epoch 9: Train Loss: 0.5536, Train Accuracy: 78.27%, Val Loss: 0.5981, Val Accuracy: 77.02%
# Epoch 10/15: 100%|██████████| 259/259 [00:30<00:00,  8.42it/s, Loss=0.5004, Accuracy=79.53%]
# Epoch 10: Train Loss: 0.5244, Train Accuracy: 79.53%, Val Loss: 0.5726, Val Accuracy: 78.20%
# Epoch 11/15: 100%|██████████| 259/259 [00:30<00:00,  8.41it/s, Loss=0.5787, Accuracy=80.42%]
# Epoch 11: Train Loss: 0.5107, Train Accuracy: 80.42%, Val Loss: 0.5720, Val Accuracy: 78.16%
# Epoch 12/15: 100%|██████████| 259/259 [00:30<00:00,  8.44it/s, Loss=0.5964, Accuracy=80.74%]
# Epoch 12: Train Loss: 0.4877, Train Accuracy: 80.74%, Val Loss: 0.5679, Val Accuracy: 79.17%
# Epoch 13/15: 100%|██████████| 259/259 [00:30<00:00,  8.43it/s, Loss=0.4353, Accuracy=81.73%]
# Epoch 13: Train Loss: 0.4687, Train Accuracy: 81.73%, Val Loss: 0.5422, Val Accuracy: 78.92%
# Epoch 14/15: 100%|██████████| 259/259 [00:30<00:00,  8.44it/s, Loss=0.5057, Accuracy=82.32%]
# Epoch 14: Train Loss: 0.4593, Train Accuracy: 82.32%, Val Loss: 0.5468, Val Accuracy: 79.38%
# Epoch 15/15: 100%|██████████| 259/259 [00:30<00:00,  8.41it/s, Loss=0.4811, Accuracy=82.03%]
# Epoch 15: Train Loss: 0.4570, Train Accuracy: 82.03%, Val Loss: 0.5557, Val Accuracy: 79.17%
# ✅ Model training complete!

# %% [markdown]
# # Model Validation and Testing Script

# %%
# Data Loading and Preprocessing (Similar to Training Script)
class MedicalImageDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.image_paths = []
        self.labels = []
        self.class_to_idx = {}
        
        self.load_images()

    def load_images(self):
        for subset in ['test', 'val']:  # Focus on test and validation sets
            subset_path = os.path.join(self.root_dir, subset)
            
            if os.path.exists(subset_path):
                for class_name in os.listdir(subset_path):
                    class_path = os.path.join(subset_path, class_name)
                    
                    if os.path.isdir(class_path):
                        if class_name not in self.class_to_idx:
                            self.class_to_idx[class_name] = len(self.class_to_idx)
                        
                        for img_name in os.listdir(class_path):
                            img_path = os.path.join(class_path, img_name)
                            
                            if img_name.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tif')):
                                self.image_paths.append(img_path)
                                self.labels.append(self.class_to_idx[class_name])

        print(f"Found {len(self.image_paths)} test images across {len(self.class_to_idx)} classes")
        print("Class mapping:", self.class_to_idx)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        label = self.labels[idx]

        try:
            image = Image.open(img_path).convert("RGB")
        except Exception as e:
            print(f"Error loading image {img_path}: {e}")
            image = Image.fromarray(np.zeros((224, 224, 3), dtype=np.uint8))

        if self.transform:
            image = self.transform(image)

        return image, label

# %%
import os
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset, random_split
from torchvision import transforms
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (
    confusion_matrix, 
    classification_report, 
    precision_recall_fscore_support
)
from vit_pytorch import ViT

# %%
# Transforms (Same as Training Script)
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
def create_model(num_classes):
    model = ViT(
        image_size=224,
        patch_size=16,
        num_classes=num_classes,
        dim=512,
        depth=6,
        heads=8,
        mlp_dim=1024,
        dropout=0.1,
        emb_dropout=0.1
    )
    return model

# %%
def validate_model(model, test_loader, device):
    """
    Comprehensive model validation function
    
    Args:
        model (nn.Module): Trained model
        test_loader (DataLoader): Test data loader
        device (torch.device): Computing device
    
    Returns:
        dict: Validation metrics
    """
    model.eval()
    all_preds = []
    all_labels = []
    correct_predictions = 0
    total_predictions = 0

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            
            total_predictions += labels.size(0)
            correct_predictions += (predicted == labels).sum().item()
            
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    # Compute metrics
    accuracy = 100 * correct_predictions / total_predictions
    
    # Detailed Classification Report
    report = classification_report(
        all_labels, 
        all_preds, 
        target_names=list(test_loader.dataset.class_to_idx.keys())

    )
    
    # Precision, Recall, F1-Score
    precision, recall, f1, _ = precision_recall_fscore_support(
        all_labels, all_preds, average='weighted'
    )
    
    # Confusion Matrix
    cm = confusion_matrix(all_labels, all_preds)

    return {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'classification_report': report,
        'confusion_matrix': cm
    }

# %%
def plot_confusion_matrix(cm, classes, title='Confusion Matrix'):
    """
    Plot confusion matrix using seaborn
    """
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=classes, 
                yticklabels=classes)
    plt.title(title)
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.tight_layout()
    plt.savefig('confusion_matrix.png')
    plt.close()

# %%
def main():
    # Configuration
    BASE_PATH = r"/kaggle/input/updated-medical-image-dataset/new_dataset"  # Update with your path
    MODEL_PATH = "/kaggle/working/final_medical_vit_model.pth"
    BATCH_SIZE = 32

    # Device
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")

    # Test Dataset
    task_datasets = []
    all_class_to_idx = {}

    for task_folder in os.listdir(BASE_PATH):
        task_path = os.path.join(BASE_PATH, task_folder)
        if os.path.isdir(task_path):
            task_dataset = MedicalImageDataset(task_path, transform=transform)
            
            if len(task_dataset) > 0:
                task_datasets.append(task_dataset)
                all_class_to_idx.update(task_dataset.class_to_idx)

    # Test DataLoader
    test_loader = DataLoader(
        task_datasets[0],  # Use first dataset for testing
        batch_size=BATCH_SIZE, 
        shuffle=False, 
        num_workers=4
    )

    # Model
    num_classes = len(all_class_to_idx)
    model = create_model(num_classes)
    
    # Load trained weights
    model.load_state_dict(torch.load(MODEL_PATH, weights_only=True))
    model = model.to(device)

    # Validation
    validation_results = validate_model(model, test_loader, device)

    # Print Results
    print("\n🔍 Model Validation Results:")
    print(f"Accuracy: {validation_results['accuracy']:.2f}%")
    print(f"Precision: {validation_results['precision']:.4f}")
    print(f"Recall: {validation_results['recall']:.4f}")
    print(f"F1 Score: {validation_results['f1_score']:.4f}")

    # Print Detailed Classification Report
    print("\n📊 Classification Report:")
    print(validation_results['classification_report'])

    # Plot Confusion Matrix
    plot_confusion_matrix(
        validation_results['confusion_matrix'], 
        list(test_loader.dataset.class_to_idx.keys())
    )

# %%
if __name__ == "__main__":
    main()
# Out:
# Using device: cuda
# Found 140 test images across 10 classes
# Class mapping: {'Avulsion fracture': 0, 'Spiral Fracture': 1, 'Impacted fracture': 2, 'Hairline Fracture': 3, 'Greenstick fracture': 4, 'Pathological fracture': 5, 'Oblique fracture': 6, 'Fracture Dislocation': 7, 'Longitudinal fracture': 8, 'Comminuted fracture': 9}
# Found 387 test images across 7 classes
# Class mapping: {'squamous.cell.carcinoma': 0, 'normal': 1, 'adenocarcinoma': 2, 'large.cell.carcinoma': 3, 'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 4, 'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 5, 'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 6}
# Found 660 test images across 2 classes
# Class mapping: {'benign': 0, 'malignant': 1}
# Found 1311 test images across 4 classes
# Class mapping: {'pituitary': 0, 'notumor': 1, 'meningioma': 2, 'glioma': 3}
#
# 🔍 Model Validation Results:
# Accuracy: 22.86%
# Precision: 0.3096
# Recall: 0.2286
# F1 Score: 0.2197
#
# 📊 Classification Report:
#                        precision    recall  f1-score   support
#
#     Avulsion fracture       0.25      0.21      0.23        14
#       Spiral Fracture       0.14      0.08      0.11        12
#     Impacted fracture       0.27      0.44      0.33         9
#     Hairline Fracture       0.00      0.00      0.00        10
#   Greenstick fracture       0.25      0.31      0.28        16
# Pathological fracture       0.23      0.28      0.25        18
#      Oblique fracture       0.25      0.19      0.21        16
#  Fracture Dislocation       0.43      0.16      0.23        19
# Longitudinal fracture       1.00      0.08      0.15        12
#   Comminuted fracture       0.25      0.50      0.33        14
#
#              accuracy                           0.23       140
#             macro avg       0.31      0.23      0.21       140
#          weighted avg       0.31      0.23      0.22       140
